# %%
import pandas as pd

# %%
combinations = pd.read_table("./data/AncientGreekUnicodeCombinations.txt")

# %%
combinations.head(50)
# Out:
#    Unicode_Char CodePoint Codepoint_hexa composed_char  \
# 0             Α       913          U+391             Α
# 1             Ᾰ      8120         U+1FB8            Ᾰ
# 2             Ᾱ      8121         U+1FB9            Α¯
# 3             ᾼ      8124         U+1FBC            ᾼ
# 4             Ά       902          U+386            Ά
# 5            Άͅ   902-837    U+386-U+345           Άͅ
# 6             Ὰ      8122         U+1FBA            Ὰ
# 7            Ὰͅ  8122-837   U+1FBA-U+345           Ὰͅ
# 8            Ὰͅ  8122-837   U+1FBA-U+345           Ὰͅ
# 9             Ἀ      7944         U+1F08            Ἀ
# 10            ᾈ      8072         U+1F88           ᾈ
# 11            Ἄ      7948         U+1F0C           Ἄ
# 12            ᾌ      8076         U+1F8C          ᾌ
# 13            Ἂ      7946         U+1F0A           Ἂ
# 14           ᾊ  7946-837   U+1F0A-U+345          ᾊ
# 15            Ἆ      7950         U+1F0E           Ἆ
# ...
